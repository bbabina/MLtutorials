# %%
import pandas as pd
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10) #test_data=20% training data 80%

# %%
X_train #chooses random samples  random_state makes the sample same
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
y_train
# Out:
# 3     40000
# 18    12800
# 13    27500
# 2     26100
# 14    19400
# 8     12000
# 17    19700
# 16    35500
# 19    28200
# 12    26000
# 11    19500
# 1     34000
# 0     18000
# 15    35000
# 4     31500
# 9     22000
# Name: Sell Price($), dtype: int64

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([20474.0745775 , 16352.07892168, 25174.14834912, 27197.42175439])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test, y_test)
# Out:
# 0.733233959309014

# %% [markdown]
# # LOGISTIC REGRESSION

# %% [markdown]
# # Binary Classification

# %%
import pandas as pd
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='+',color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
X_test
# Out:
#     age
# 3    52
# 21   26
# 22   40

# %%
X_train
# Out:
#     age
# 8    62
# 24   50
# 18   19
# 9    61
# 12   27
# 20   21
# 10   18
# 11   28
# 0    22
# 16   25
# 23   45
# 2    47
# 17   58
# 14   49
# 15   55
# 13   29
# 7    60
# 19   18
# 6    55
# 5    56
# 25   54
# 1    25
# 4    46
# 26   23

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)   #.fit is model training
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1], dtype=int64)

# %%
model.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_proba(X_test)
# Out:
# array([[0.0913837 , 0.9086163 ],
#        [0.85430697, 0.14569303],
#        [0.39641996, 0.60358004]])

# %%
model.predict([[50]])
# Out:
# array([1], dtype=int64)

# %%
model.predict([[23]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # MULTICLASS CLASSIFICATION

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
plt.gray()
for i in range(5):
    plt.matshow(digits.images[i])

# %%
digits.target[0:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.2)

# %%
len(X_test)
# Out:
# 360

# %%
len(y_test)
# Out:
# 360

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# c:\users\epoch\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.9611111111111111

# %%
plt.matshow(digits.images[67])

# %%
digits.target[67]
# Out:
# 6

# %%
model.predict([digits.data[67]])
# Out:
# array([6])

# %%
model.predict(digits.data[0:5])
# Out:
# array([0, 1, 2, 3, 4])

# %%
y_predicted = model.pre
from sklearn.metrics import confusion_matrix
